# %%
from ultralytics import YOLO
import torch
import cv2
import matplotlib.pyplot as plt
import numpy as np
from scipy.signal import wiener
import time

# %%
model = YOLO('../yolo-road-signs/road-signs-yolov8n.pt')

# %%
cap = cv2.VideoCapture('../data/train_videos/AKN00077.mp4')

# %%
cap.set(cv2.CAP_PROP_POS_FRAMES, 5040)
# Out:
# True

# %%
success, frame = cap.read()
frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
plt.figure(figsize=(6, 4))
plt.imshow(frame)

tstart = time.time()
marked_frame = model(frame, conf=0.6)
print(time.time() - tstart)

plt.figure(figsize=(6, 4))
plt.imshow(marked_frame[0].plot())
# Out:
# 0: 384x640 2 ---------- -------s, 2.7ms
# Speed: 1.0ms preprocess, 2.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# 0.06795907020568848

# %%
are_signs = True if marked_frame[0].boxes.shape[0] > 0 else False
are_signs
# Out:
# True
